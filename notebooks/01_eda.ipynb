# %% [markdown]
# # 01 — Exploratory Data Analysis (EDA)
#
# **Project:** Walmart Store Sales Forecasting & Retail Analytics in Snowflake
#
# This notebook explores the Kaggle dataset locally before (or alongside) Snowflake ingestion.
#
# ## Goals
# - Load and profile `train`, `test`, `features`, and `stores`
# - Understand sales distribution, seasonality, and holiday effects
# - Check missing values in markdown and economic features
# - Inform staging and marts design
#
# ## Data location
# Place CSV files in `../data/` (gitignored). Adjust paths below if needed.

# %%
# TODO: Uncomment after placing CSVs in ../data/
# import pandas as pd
# import matplotlib.pyplot as plt
# import seaborn as sns
#
# DATA_PATH = "../data/"
#
# train = pd.read_csv(f"{DATA_PATH}train.csv", parse_dates=["Date"])
# test = pd.read_csv(f"{DATA_PATH}test.csv", parse_dates=["Date"])
# features = pd.read_csv(f"{DATA_PATH}features.csv", parse_dates=["Date"])
# stores = pd.read_csv(f"{DATA_PATH}stores.csv")
#
# print("Train shape:", train.shape)
# train.head()

# %% [markdown]
# ## TODO — Analysis sections
#
# 1. **Summary statistics** — `Weekly_Sales` by Store, Dept, IsHoliday
# 2. **Store type analysis** — join `stores`, compare Type A/B/C
# 3. **Seasonality** — weekly/monthly sales trends
# 4. **Holiday impact** — avg sales when `IsHoliday == True`
# 5. **Feature exploration** — Temperature, Fuel_Price, MarkDown1–5, CPI, Unemployment
# 6. **Missing values** — especially markdown and CPI columns
