# %% [markdown]
# # 02 — Sales Forecasting (Optional)
#
# **Project:** Walmart Store Sales Forecasting & Retail Analytics in Snowflake
#
# Baseline forecasting workflow using historical `train.csv` and holdout `test.csv`.
#
# ## Goals
# - Engineer time-based features (lags, rolling averages)
# - Join store features where useful
# - Train a simple baseline model (e.g., linear regression or seasonal naive)
# - Evaluate with MAE / MAPE on test period
#
# > This notebook is optional for the portfolio but demonstrates ML literacy.

# %%
# TODO: Implement forecasting pipeline
# from sklearn.model_selection import train_test_split
# from sklearn.metrics import mean_absolute_error, mean_absolute_percentage_error
#
# Steps:
# 1. Load train.csv and features.csv
# 2. Create lag features per Store + Dept
# 3. Split by date (align with Kaggle test period)
# 4. Fit baseline model
# 5. Score and document MAPE
