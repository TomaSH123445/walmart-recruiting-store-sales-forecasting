# %% [markdown]
# # 03 — Data Quality Checks (Python)
#
# **Project:** Walmart Store Sales Forecasting & Retail Analytics in Snowflake
#
# Python-side validation to complement `sql/08_data_quality_checks.sql`.
#
# ## Goals
# - Profile each CSV ( dtypes, nulls, duplicates )
# - Validate referential integrity (Store keys across files)
# - Flag outliers in `Weekly_Sales`
# - Document checks for portfolio README

# %%
# TODO: Data quality checks
#
# def check_duplicates(df, keys):
#     """Return rows where natural key is duplicated."""
#     return df[df.duplicated(subset=keys, keep=False)]
#
# # Example: check_duplicates(train, ["Store", "Dept", "Date"])
#
# Checks to implement:
# - Duplicate Store + Dept + Date in train
# - Orphan stores (in train but not in stores.csv)
# - Missing Store + Date in features for train dates
# - Negative or zero Weekly_Sales counts
